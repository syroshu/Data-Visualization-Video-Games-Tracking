# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('games.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
region = df.drop(columns = ['Rank', 'Year', 'Genre', 'Name', 'Platform', 'Publisher'])
region
# Out:
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0         41.49     29.02      3.77         8.46         82.74
# 1         29.08      3.58      6.81         0.77         40.24
# 2         15.85     12.88      3.79         3.31         35.82
# 3         15.75     11.01      3.28         2.96         33.00
# 4         11.27      8.89     10.22         1.00         31.37
# ...         ...       ...       ...          ...           ...
# 16593      0.01      0.00      0.00         0.00          0.01
# 16594      0.01      0.00      0.00         0.00          0.01
# 16595      0.00      0.00      0.00         0.00          0.01
# 16596      0.00      0.01      0.00         0.00          0.01
# 16597      0.01      0.00      0.00         0.00          0.01
#
# [16598 rows x 5 columns]

# %%
publisher = df.drop(columns = ['Rank', 'Year', 'Genre', 'Name'])
publisher
# Out:
#       Platform   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0          Wii    Nintendo     41.49     29.02      3.77         8.46
# 1          NES    Nintendo     29.08      3.58      6.81         0.77
# 2          Wii    Nintendo     15.85     12.88      3.79         3.31
# 3          Wii    Nintendo     15.75     11.01      3.28         2.96
# 4           GB    Nintendo     11.27      8.89     10.22         1.00
# ...        ...         ...       ...       ...       ...          ...
# 16593      GBA       Kemco      0.01      0.00      0.00         0.00
# 16594       GC  Infogrames      0.01      0.00      0.00         0.00
# 16595      PS2  Activision      0.00      0.00      0.00         0.00
# 16596       DS    7G//AMES      0.00      0.01      0.00         0.00
# 16597      GBA     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# ...

# %%
publisher = publisher.groupby('Publisher').sum()
publisher
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# 10TACLE Studios                   0.07      0.04      0.00         0.00
# 1C Company                        0.01      0.07      0.00         0.02
# 20th Century Fox Video Games      1.82      0.10      0.00         0.01
# 2D Boy                            0.00      0.03      0.00         0.01
# 3DO                               6.48      3.04      0.00         0.63
# ...                                ...       ...       ...          ...
# id Software                       0.02      0.00      0.00         0.00
# imageepoch Inc.                   0.00      0.00      0.04         0.00
# inXile Entertainment              0.02      0.06      0.00         0.01
# mixi, Inc                         0.00      0.00      0.86         0.00
# responDESIGN                      0.09      0.04      0.00         0.01
#
#                               Global_Sales
# Publisher
# ...

# %%
publisher = publisher.sort_values(by=['Global_Sales'], ascending=False).head()
publisher
# Out:
#                              NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                       816.87    418.74    455.42        95.33
# Electronic Arts                595.07    371.27     14.04       129.77
# Activision                     429.70    215.53      6.54        75.34
# Sony Computer Entertainment    265.22    187.72     74.10        80.45
# Ubisoft                        253.43    163.32      7.50        50.26
#
#                              Global_Sales
# Publisher
# Nintendo                          1786.56
# Electronic Arts                   1110.32
# Activision                         727.46
# Sony Computer Entertainment        607.50
# Ubisoft                            474.72

# %%
publisher = publisher.rename(index={'Electronic Arts':'EA', 'Sony Computer Entertainment': 'Sony'})
publisher
# Out:
#             NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Publisher
# Nintendo      816.87    418.74    455.42        95.33       1786.56
# EA            595.07    371.27     14.04       129.77       1110.32
# Activision    429.70    215.53      6.54        75.34        727.46
# Sony          265.22    187.72     74.10        80.45        607.50
# Ubisoft       253.43    163.32      7.50        50.26        474.72

# %%
publisher = publisher.sort_values(by=['Global_Sales'], ascending=True)
publisher
# Out:
#             NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Publisher
# Ubisoft       253.43    163.32      7.50        50.26        474.72
# Sony          265.22    187.72     74.10        80.45        607.50
# Activision    429.70    215.53      6.54        75.34        727.46
# EA            595.07    371.27     14.04       129.77       1110.32
# Nintendo      816.87    418.74    455.42        95.33       1786.56

# %%
plt.style.use("bmh")

# %%
fig, ax = plt.subplots()
ax.bar(publisher.index, publisher['Global_Sales'], color=(0.1,0.6,0.5))
ax.set_xlabel('Publisher',labelpad=10, color=(0.1,0.6,0.5))
ax.set_ylabel("Global Sales Rate", labelpad=10, color=(0.1,0.6,0.5))
plt.show()
